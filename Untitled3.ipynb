# %% [markdown]
# <a href="https://colab.research.google.com/github/dasmeghalay20/expense-tracker-app/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os

file_name = "expenses.csv"

# %%
# load data from file
def load_data():
    expenses = []
    if os.path.exists(file_name):
        with open(file_name, "r") as f:
            reader = csv.DictReader(f)
            for row in reader:
                row["amount"] = float(row["amount"])
                expenses.append(row)
    return expenses

# %%
# save data to file
def save_data(expenses):
    with open(file_name, "w", newline="") as f:
        fields = ["date", "category", "description", "amount"]
        writer = csv.DictWriter(f, fieldnames=fields)
        writer.writeheader()
        writer.writerows(expenses)

# %%
# add expense
def add_expense(expenses):
    date = input("Enter date: ")
    category = input("Enter category: ")
    description = input("Enter description: ")
    amount = float(input("Enter amount: "))

    expense = {
        "date": date,
        "category": category,
        "description": description,
        "amount": amount
    }

    expenses.append(expense)
    save_data(expenses)
    print("Expense added successfully.\n")

# %%
# view expenses
def view_expenses(expenses):
    if not expenses:
        print("No expenses found.\n")
        return

    print("\nAll Expenses:")
    for i in range(len(expenses)):
        e = expenses[i]
        print(f"{i+1}. {e['date']} | {e['category']} | {e['description']} | ₹{e['amount']}")
    print()

# %%
# total expense
def total_expense(expenses):
    total = 0
    for e in expenses:
        total += e["amount"]
    print("Total Spending: ₹", total, "\n")

# %%
# main program
expenses = load_data()

while True:
    print("==== Expense Tracker ====")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Total Spending")
    print("4. Exit")

    choice = input("Enter choice: ")

    if choice == "1":
        add_expense(expenses)
    elif choice == "2":
        view_expenses(expenses)
    elif choice == "3":
        total_expense(expenses)
    elif choice == "4":
        print("Thank you for using Expense Tracker!")
        break
    else:
        print("Invalid choice.\n")
# Out:
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Enter choice: 1
# Enter date: 22/02/2026
# Enter category: food
# Enter description: chips+drinks
# Enter amount: 200
# Expense added successfully.
#
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
# Enter choice: 3
# Total Spending: ₹ 200.0
#
# ==== Expense Tracker ====
# 1. Add Expense
# 2. View Expenses
# 3. Total Spending
# 4. Exit
